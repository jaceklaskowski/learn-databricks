# %% [markdown]
# # New Meetup
#
# Warsaw AI Engineering & LLMOps (GenAI | MLflow | Agents | Databricks)
#
# It balances:
#
# * clarity
# * SEO/discoverability
# * modern stack relevance
#
# Talks about agentic systems, LangChain and MLflow in production, RAGs and GenAI workflows.

# %% [markdown]
# ## Prompt
#
# I'm considering closing the existing Warsaw Data Engineering meetup group and focus more on AI and ML Engineering, particularly on MLflow (incl. Databricks), language models and LLMOps. I'd like to focus on GenAI and helping Data Scientist teams productionalizing their jupyter/pandas/transformers-heavy notebooks.
#
# What'd be the title of the meetup? How to describe its purpose and goals?

# %% [markdown]
# ## Copilot
#
# That's a strong pivot—very aligned with where the industry is moving. Shifting from generic Data Engineering to ML Engineering + MLOps + GenAI + productionization will attract a more focused, high-value audience.

# %% [markdown]
# ## Positioning (what this meetup is about)
#
# Here's a concise positioning statement you can reuse:
#
# A meetup focused on turning machine learning from notebooks into production systems. We explore ML Engineering, MLOps, MLflow, Databricks, and GenAI—helping teams ship reliable, scalable AI solutions.

# %% [markdown]
# ## Full Meetup Description
#
# Warsaw ML Engineering & MLOps Meetup (MLflow | Databricks | GenAI)
#
# This meetup is for engineers and data scientists who want to move beyond prototypes and build real-world, production-grade machine learning systems.
# We focus on the practical side of ML:
#
# How to productionize Jupyter notebook workflows
# How to manage experiments, models, and pipelines with MLflow
# How to deploy and operate ML systems on platforms like Databricks
# How to build and scale GenAI applications (LLMs, RAG, agents)
# How to design reliable, testable, and maintainable ML pipelines
#
# This is NOT a research meetup.
# This is about shipping ML to production.
# 👥 Who is this for?
#
# ML Engineers
# Data Engineers moving into ML
# Data Scientists who want to productionize their work
# Platform engineers building ML infrastructure
#
# ⚙️ Topics we'll cover
#
# MLflow (tracking, registry, deployments)
# Databricks & modern ML platforms
# MLOps best practices
# CI/CD for ML pipelines
# Feature engineering & feature stores
# Model monitoring & observability
# GenAI systems (RAG, evaluation, orchestration)
# Scaling Python / Pandas workloads
# Reproducibility & experiment management
#
# 🎯 Format
#
# Real-world case studies
# Live demos (not just slides)
# Lessons from production systems
# Failures & trade-offs (what doesn’t work)

# %% [markdown]
# ## Purpose & Goals
#
# 🎯 Core Mission
#
# Help teams turn ML experiments into reliable, scalable production systems.
#
# ✅ Concrete goals
#
# * Bridge the gap between data science and engineering
# * Promote production-first thinking
# * Share real-world architectures and lessons
# * Build a community of practitioners (not just learners)
# * Encourage tooling standardization (MLflow, Databricks, etc.)
# * Accelerate adoption of GenAI in production environments

# %% [markdown]
# ## Clear Differentiation (important)
#
# You want to explicitly position this differently from typical meetups:
#
# Not:
#
# * pure AI hype
# * academic talks
# * beginner tutorials
#
# Instead:
#
# * hands-on
# * production-focused
# * engineering-heavy
# * opinionated
#
# 👉 Add a line like:
#
# We prioritize real-world production experience over theoretical discussions.
#
# Targeting practitioners using Databricks/MLflow

# %% [markdown]
# ## Optional Tagline Ideas
#
# You can add one under the title:
#
# * "From Notebook to Production"
# * "Shipping ML, not just training models"
# * "Where ML meets engineering discipline"
# * "Building real AI systems, not demos"

# %% [markdown]
# ## Bonus: First Event Topic Ideas
#
# To kick things off strongly:
#
# * "From Pandas Notebook to Production Pipeline (MLflow + Databricks)"
# * "Building a Production RAG System End-to-End"
# * "What Breaks When You Deploy Your First ML Model"
# * "MLflow in Practice: Tracking, Registry, and Deployment"
# * "Refactoring Data Science Code into Maintainable Systems"
