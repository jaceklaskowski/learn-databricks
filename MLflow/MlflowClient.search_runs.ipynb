# %% [markdown]
# # MlflowClient.search_runs

# %%
# %pip install -U mlflow-skinny[databricks]>=3.12
# %restart_python

# %%
from mlflow.client import MlflowClient

mlflow_client = MlflowClient()
mlflow_client.search_runs(experiment_ids=[<your_experiment_id>])

# %%
# %sql

CREATE TABLE jacek_mlflow.default.eval_dataset ();
