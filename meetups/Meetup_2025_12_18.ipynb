# %% [markdown]
# # Build AI Agents with DSPy and MLflow on Databricks
#
# Thursday, Dec 18, 2025
#
# [Meetup](https://www.meetup.com/warsaw-data-engineering/events/312422034/) • [LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7405679909659996160)

# %% [markdown]
# # 📚 Agenda
#
# 1. Zbudujesz autonomiczną aplikację AI do rezerwacji biletów lotniczych
# 1. Poznasz "hit poprzedniego spotkania" **dspy.ReAct**
#
# ⏰ Całkowity czas trwania spotkania: **1h 15min**

# %% [markdown]
# # 📈 LinkedIn Poll
#
# [Poll](https://www.linkedin.com/feed/update/urn:li:activity:7302063410647638016?) <-- O co chcielibyście zapytać w kolejnej ankiecie? 🤔

# %% [markdown]
# # 🙋‍♀️ Event Question
#
# [O czym chciał(a)byś usłyszeć podczas meetupu? Rzuć ciekawym pomysłem na kolejne edycje](https://www.meetup.com/warsaw-data-engineering/events/312422034/attendees/) 🙏
#
# 1. Chciałbym się dowiedzieć jak działają agenci na platformie databricks i sprawdzić ich potencjał do wykorzystania w projektach u klientów lub do przyśpieszenia sobie codziennej pracy
# 1. evals
# 1. Coś przydatnego w inżynierii danych, różne rodzaje wykorzystania go jakich scenariuszy warto rozważać
# 1. databricks

# %% [markdown]
# # 📢 News
#
# Things worth watching out for...

# %% [markdown]
# ## New members in Warsaw Data Engineering!
#
# [You now have 642 members!](https://www.meetup.com/warsaw-data-engineering/)

# %% [markdown]
# ## New Versions
#
# What has changed in the tooling space since we last met? I.e. hunting down the features to learn more about.
#
# * [Cursor 2.2.36](https://cursor.com/changelog/2-2)
# * [Databricks CLI 0.281.0](https://github.com/databricks/cli/releases/tag/v0.281.0)
# * [MLflow 3.8.0rc0](https://github.com/mlflow/mlflow/releases/tag/v3.8.0rc0)
# * [Pydantic AI 1.35.0](https://github.com/pydantic/pydantic-ai/releases/tag/v1.35.0)
# * [uv 0.9.18](https://github.com/astral-sh/uv/releases/tag/0.9.18)

# %% [markdown]
# # 🧑‍💻 Demo 1️⃣: Live Coding Session
#
# 1. [Build AI Agents with DSPy and MLflow on Databricks]($../DSPy/Build AI Agents with DSPy and MLflow on Databricks)
# 1. [dspy.ReAct]($../DSPy/dspy.ReAct)
# 1. [Text Classifier DSPy Program]($../DSPy/Text Classifier DSPy Program)
# 1. [Tracking DSPy Optimizers with MLflow]($../DSPy/Tracking DSPy Optimizers with MLflow)
# 1. Deep Dive into [MLflow DSPy Autologging]($../MLflow/MLflow DSPy Autologging)
# 1. [Use MLflow to Track PyTorch Deep Learning Experiments]($../MLflow/Use MLflow to Track PyTorch Deep Learning Experiments)

# %% [markdown]
# # That's all Folks! 👋
#
# ![Warner Bros., Public domain, via Wikimedia Commons](https://upload.wikimedia.org/wikipedia/commons/e/ea/Thats_all_folks.svg)

# %% [markdown]
# # 🙋 Questions and Answers

# %% [markdown]
# # 💡 Ideas for Future Events
#
# ➡️ [Ideas for Future Events]($./Ideas for Future Events)
