# %% [markdown]
# # Evaluating LLMs and Agents with MLflow
#
# Tuesday, Jun 23, 2026
#
# [Meetup](https://www.meetup.com/warsaw-ai-engineering/events/315242914/) • [LinkedIn](https://www.linkedin.com/groups/29050000/)

# %% [markdown]
# # 📚 Agenda
#
# 1. Dokończymy tutorial [End-to-End RAG Evaluation]($../MLflow/MLflow's End-to-End RAG Evaluation) od momentu użycia `mlflow.genai.evaluate`
#     * LM
#     * Model Version
#     * Parameters
#     * Prompt
# 1. Dowiesz się, czym jest [MLflow Evaluation](https://mlflow.org/docs/latest/genai/eval-monitor/)
# 1. Spróbujemy uruchomić [End-to-End RAG Evaluation]($../MLflow/MLflow's End-to-End RAG Evaluation) tutorial lokalnie z użyciem [JupyterLab: A Next-Generation Notebook Interface](https://jupyter.org/) 🤞
#
# ⏰ Całkowity czas trwania spotkania: **1h 15min**

# %% [markdown]
# # That's all Folks! 👋
#
# ![Warner Bros., Public domain, via Wikimedia Commons](https://upload.wikimedia.org/wikipedia/commons/e/ea/Thats_all_folks.svg)
