# %% [markdown]
# # WIP Lakeflow Spark Declarative Pipelines
#
# | 🚨 Consider a WIP until this message goes away... 🚨 |
# |-|
#
# [Lakeflow Spark Declarative Pipelines](https://docs.databricks.com/aws/en/ldp/)

# %% [markdown]
# ## Questions from Attendees
#
# 1. jak to połączyć z delta tables
# 1. reading incremental data from files
# 1. FEFD <--- ☠️🔥☠️🔥☠️

# %% [markdown]
# ## Spark Pipelines CLI
#
# The entry point to all things Spark Declarative Pipelines is [spark-pipelines](https://books.japila.pl/spark-sql-internals/declarative-pipelines/#spark-pipelines) shell script.

# %% [markdown]
# Run `spark-pipelines` script and you face the following issue:
#
# <br>
#
# ```shell
# $ ./bin/spark-pipelines
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/22 17:32:22 WARN Utils: Your hostname, Jaceks-Mac-mini-2.local, resolves to a loopback address: 127.0.0.1; using 192.168.68.100 instead (on interface en1)
# 26/01/22 17:32:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Traceback (most recent call last):
#   File "/Users/jacek/oss/spark/python/pyspark/pipelines/cli.py", line 29, in <module>
#     import yaml
# ModuleNotFoundError: No module named 'yaml'
# ```

# %% [markdown]
# ## Run SDP with uv
#
# Run SDP on command line using [uvx](https://docs.astral.sh/uv/guides/tools/).
#
# <br>
#
# ```sh
# uvx --with "pyspark[pipelines]==4.1.1" spark-pipelines --help
# ```
#
# NOTE: I learnt it while reviewing [Installation requirements for using the create-dagster CLI](https://docs.dagster.io/getting-started/installation#installation-requirements-for-using-the-create-dagster-cli).
