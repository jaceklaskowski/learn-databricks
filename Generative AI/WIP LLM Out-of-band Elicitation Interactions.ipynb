# %% [markdown]
# # WIP LLM Out-of-band Elicitation Interactions
#
# | 🚨 Consider a WIP until this message goes away... 🚨 |
# |-|

# %% [markdown]
# ## Resources
#
# 1. I found this term "LLM Out-of-band Elicitation Interactions" in [this commit in evalstate/fast-agent](https://github.com/evalstate/fast-agent/commit/eee1d59868880b4e33199c3f6be6a9508e4dd271) and got curious
# 1. Needs even more? Try [this Google search](https://www.google.com/search?q=llm+out-of-band+interactions) 😉
