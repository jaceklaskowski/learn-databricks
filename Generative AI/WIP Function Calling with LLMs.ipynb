# %% [markdown]
# # WIP Function Calling with LLMs
#
# | 🚨 Consider a WIP until this message goes away... 🚨 |
# |-|
#
# _Function Calling-Capable LLMs_

# %% [markdown]
# ## Prompt
#
# **Prompt** is a structured text input to communicate a specific task or query to a language model, guiding it to produce the desired output.
