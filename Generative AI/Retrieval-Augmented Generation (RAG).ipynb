-- %% [markdown]
-- # Retrieval-Augmented Generation (RAG)

-- %% [markdown]
-- [Retrieval Augmented Generation](https://www.databricks.com/glossary/retrieval-augmented-generation-rag):
--
-- > **Retrieval augmented generation** or **RAG** is an architectural approach that can improve the efficacy of large language model (LLM) applications by leveraging custom data.
--
-- > This is done by retrieving relevant data/documents relevant to a question or task and providing them as context for the LLM. RAG has shown success in support chatbots and Q&A systems that need to maintain up-to-date information or access domain-specific knowledge.
--
-- RAG combines language models with additional information retrieval techniques for more accurate and contextually-relevant responses.
--
-- Let the LLMs enhance their responses with external data (specialized datasets like legal documents).

-- %% [markdown]
-- ## RAG and Embedding Vectors
--
-- Firstly, a RAG solution should transform additional information (documents) into vectors (known as **embedding vectors** or simply **embeddings**).
-- The embeddings are then stored in a vector database.
--
-- Upon receiving a user query, the RAG solution searches these for relevant embeddings which are added to a prompt (to be sent to a LLM).
--
-- Adds more accurate, context-aware, and current knowledge to the prompts (for the LLMs to learn from and use to generate a response).
--
-- Responses are enriched with external data, minimizing inaccuracies and improving relevance

-- %% [markdown]
-- ## Creating High Quality RAG Applications with Databricks
--
-- [Creating High Quality RAG Applications with Databricks](https://www.databricks.com/blog/building-high-quality-rag-applications-databricks)

-- %% [markdown]
-- > a powerful way to incorporate proprietary, real-time data into Large Language Model (LLM) applications.

-- %% [markdown]
-- ## Example: Chatbot
--
-- Develop a chatbot to assist legal researchers by providing answers based on extensive legal documents.
