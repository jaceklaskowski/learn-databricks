# %% [markdown]
# # WIP Model Context Protocol (MCP) on Databricks
#
# | 🚨 Consider a WIP until this message goes away... 🚨 |
# |-|
#
# [Model Context Protocol (MCP) on Databricks](https://docs.databricks.com/aws/en/generative-ai/mcp)
