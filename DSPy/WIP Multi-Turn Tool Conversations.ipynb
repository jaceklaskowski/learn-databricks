# %% [markdown]
# # WIP Multi-Turn Tool Conversations
#
# | 🚨 Consider a WIP until this message goes away... 🚨 |
# |-|

# %% [markdown]
# ## Resources
#
# 1. LangChain Tutorial on [Test multi-turn conversations](https://docs.langchain.com/langsmith/multiple-messages)
# 1. Microsoft Agent Framework's [Multi-turn conversations with an agent](https://learn.microsoft.com/en-us/agent-framework/tutorials/agents/multi-turn-conversation?pivots=programming-language-python)
# 1. I found this term "Multi-Turn Tool Conversations" in [evalstate/fast-agent/pull/578](https://github.com/evalstate/fast-agent/pull/578) and got curious how it's different from DSPy's ReAct. Review it once again once some reading's done.
# 1. Needs even more? Try [this Google search](https://www.google.com/search?q=multi-turn+tool+conversations) 😉
