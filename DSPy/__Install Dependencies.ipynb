# %% [markdown]
# # Install Dependencies
#
# This notebook installs the latest versions of the required dependencies:
#
# * [MLflow](https://mlflow.org/)
# * [DSPy](https://dspy.ai/)
#
# It is supposed to be called using [%run](https://docs.databricks.com/aws/en/notebooks/notebooks-code#use-magic-commands) magic command (as shown in the following cell).

# %%
# %skip

# %run "./__Install Dependencies"

# %%
# %pip install -qU dspy>=3.0.4 mlflow>=3.8.1
# %restart_python

# %%
import mlflow
print(f"MLflow version: {mlflow.__version__}")

# to be notified about a possible upgrade in the meantime
assert mlflow.__version__ == "3.8.1"

# %%
import dspy
print(f"DSPy version: {dspy.__version__}")

# to be notified about a possible upgrade in the meantime
assert dspy.__version__ == "3.0.4"
