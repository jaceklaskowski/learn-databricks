# %% [markdown]
# # WIP Reflective Prompt Evolution with GEPA
#
# | 🚨 Consider a WIP until this message goes away... 🚨 |
# |-|

# %% [markdown]
# ## Learning Resources
#
# 1. [Reflective Prompt Evolution with GEPA](https://dspy.ai/tutorials/gepa_ai_program/)
# 1. [GEPA: Reflective Prompt Evolution Can Outperform Reinforcement Learning](https://arxiv.org/abs/2507.19457) (arXiv:2507.19457)
# 1. [gepa-ai/gepa](https://github.com/gepa-ai/gepa)
# 1. Needs even more? Try [this Google search](https://www.google.com/search?q=multi-turn+tool+conversations) 😉
