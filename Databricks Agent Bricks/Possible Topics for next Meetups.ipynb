# %% [markdown]
# # 💡 Possible Topics for next Meetups
#
# Remove the notebook once the topic ideas have been "processed".
#
# 1. [Manage supervisor agents using the Databricks SDK](https://docs.databricks.com/aws/en/generative-ai/agent-bricks/multi-agent-supervisor#manage-supervisor-agents-using-the-databricks-sdk)
# 1. [MLflow Tracing for LLM and Agent Observability](https://mlflow.org/docs/latest/genai/tracing/)

# %% [markdown]
# # 📚 README OpenAI Agents
#
# 1. https://openai.com/index/introducing-chatgpt-agent/
# 1. https://github.com/openai/openai-agents-python
# 1. https://openai.com/solutions/use-case/agents/
# 1. https://developers.openai.com/api/docs/guides/agents
# 1. https://cobusgreyling.medium.com/agentic-workflows-6d2f5340c1b5
