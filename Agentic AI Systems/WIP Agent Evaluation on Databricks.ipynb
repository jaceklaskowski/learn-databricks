# %% [markdown]
# # Agent Evaluation on Databricks
#
# [This Databricks course](https://www.databricks.com/training/catalog/agent-evaluation-on-databricks-5059) teaches students how to systematically evaluate AI agents using MLflow's evaluation framework.

# %% [markdown]
# ## 📚 Learn More
#
# 1. [What is AI Agent Evaluation?](https://www.databricks.com/blog/what-is-agent-evaluation)
# 1. [Introducing Enhanced Agent Evaluation](https://www.databricks.com/blog/introducing-enhanced-agent-evaluation)
# 1. [Evaluate and monitor AI agents](https://docs.databricks.com/aws/en/mlflow3/genai/eval-monitor/)
