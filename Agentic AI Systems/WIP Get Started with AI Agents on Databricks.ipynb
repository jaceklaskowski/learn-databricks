# %% [markdown]
# # Get Started with AI Agents on Databricks
#
# [This Databricks foundational course](https://www.databricks.com/training/catalog/get-started-with-ai-agents-on-databricks-4464) is an introduction to AI agents, their role in modern AI applications, and how to build AI agent applications on the Databricks platform.
